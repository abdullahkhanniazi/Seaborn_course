# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import random
from time import process_time

# %% [markdown]
# #### Seaborn works well with Pandas DataFrames. We'll use Seaborn’s built-in datasets for examples.

# %% [markdown]
# ##### You can use any dataset for practice like we use 2 more in practice dataset
# ##### We will use this dataset in future for Regression and multiple other machine learning algorithams

# %%
# Load tip dataset
tips = sns.load_dataset('tips')

# %% [markdown]
# ### Categorical Plots
# #### Bar Plot

# %%
sns.barplot(x='day', y='total_bill', data=tips)
plt.show()

# %%
# Customization
sns.barplot(x='day', y='total_bill', hue='sex', data=tips, palette='Blues')
plt.show()

# %%
# Example 
# Create a random dataset using NumPy
np.random.seed(42)  # For reproducibility
Subject = ['Subject A', 'Subject B', 'Subject C', 'Subject D']
values = np.random.randint(20, 100, size=4)  # Random values between 10 and 100

# Create a DataFrame using Pandas
data = pd.DataFrame({
    'Category': Subject,
    'Value': values
})

# Display the DataFrame
print(data)

# Create the barplot using Seaborn
sns.barplot(x='Category', y='Value', data=data, palette="Blues")

# Customize the plot
plt.title("Random Bar Plot Example")
plt.xlabel("Subjects")
plt.ylabel("Values")
plt.show()
# Out:
#     Category  Value
# 0  Subject A     71
# 1  Subject B     34
# 2  Subject C     91
# 3  Subject D     80
# C:\Users\Abdullah khan\AppData\Local\Temp\ipykernel_7964\2493197388.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category', y='Value', data=data, palette="Blues")

# %% [markdown]
# #### Count Plot

# %%
sns.countplot(x='day', data=tips)
plt.show()

# %% [markdown]
# #### Box Plot

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
plt.show()

# %%
# Example 
np.random.seed(42)
Subject = ['Subject A', 'Subject B', 'Subject C', 'Subject D', 'Subject E', 'Subject F']
values = np.random.randint(20, 50, size=6)

# Create a DataFrame using Pandas
data = pd.DataFrame({
    'Category': Subject,
    'Value': values
})
# here is good example when we have one value because this will not create any box plot box plot need 4 values like min
# max high and low
sns.boxplot(x='Category', y="Value", data=data)

# Customize the plot
plt.title("Count Plot Example")
plt.xlabel("Subjects")
plt.ylabel("Values")
plt.show()
# Out:
# C:\Users\Abdullah khan\AppData\Local\Temp\ipykernel_7964\2362228803.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y="Value", data=data, palette="Blues")

# %% [markdown]
# #### Violin Plot

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# #### Strip Plot

# %%
sns.stripplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# #### Swarm Plot

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# ### Relational Plots
# #### Scatter Plot

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
# Customization
sns.scatterplot(x='total_bill', y='tip', hue='sex', size='size', data=tips)
plt.show()

# %%
# Example 
np.random.seed(42)
values_1 = np.random.randint(20, 50, size=30)
values_2 = np.random.randint(20, 50, size=30)

# Create a DataFrame using Pandas
data = pd.DataFrame({
    'values_X': values_1,
    'values_Y': values_2
})
sns.scatterplot(x='values_X', y="values_Y", data=data)

plt.title("Count scatter Example")
plt.xlabel("values_X")
plt.ylabel("values_Y")
plt.show()

# %% [markdown]
# #### Line Plot

# %%
fmri = sns.load_dataset("fmri")
sns.lineplot(x="timepoint", y="signal", data=fmri)
plt.show()

# %% [markdown]
# #### Relplot

# %%
sns.relplot(x='total_bill', y='tip', hue='sex', col='day', data=tips)
plt.show()

# %% [markdown]
# ### Distribution Plots
# #### Histogram (Displot)

# %%
sns.histplot(tips['total_bill'])
plt.show()

# %% [markdown]
# #### KDE Plot

# %%
sns.kdeplot(tips['total_bill'])
plt.show()

# %% [markdown]
# #### Joint Plot

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='scatter')
plt.show()

# %% [markdown]
# ### Matrix Plots
# #### Heatmap

# %%
df = sns.load_dataset("titanic")
data_df = df.iloc[:, [0,1,3,4,5,6]]
corelation = data_df.corr()

corelation   # Correlation basically tells you how strong the relation between 2 values it range bet. [-1,1]
plt.figure(figsize=(5,5))
sns.heatmap(corelation, cbar=True,square=True,  annot=True, annot_kws={'size':8}, cmap='Blues')
plt.show()

# %% [markdown]
# ### Pair Plots
# #### Pair Plot

# %%
sns.pairplot(tips)
plt.show()

# %%
# Customization
sns.pairplot(tips, hue='sex', kind='scatter')
plt.show()

# %% [markdown]
# ### Regression Plots
# #### Regression Plot (lmplot)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)
plt.show()

# %% [markdown]
# ### FacetGrid

# %%
# Creates subplots based on the levels of a categorical variable
g = sns.FacetGrid(tips, col='sex', row='time')
g.map(sns.scatterplot, 'total_bill', 'tip')
plt.show()

# %% [markdown]
# ### Seaborn Aesthetics
# #### Style

# %%
sns.set_style("whitegrid")   # Style
sns.set_context("talk")    # Context
sns.set_palette("coolwarm")     # Palette
sns.boxplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# ## Practice

# %%
x = np.linspace(1,10,100)
a = np.sin(x)
b = np.cos(x)

# %%
plt.plot(x,a)
plt.show()

# %%
x = np.linspace(-10,10,20)
y = x**2
plt.plot(x,y,"*")
plt.show()

# %%
tips = sns.load_dataset("tips")
tips.head(10)
# tips["sex"].value_counts()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips.groupby("sex")["tip"].mean()
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
sns.relplot(data = tips, x="total_bill",col="time",y="tip",hue="smoker", style = "smoker",size="size")
plt.show()

# %%
sns.relplot(data = tips, x = "total_bill", y = "tip", hue = "smoker",size="size", col="day")
plt.show()

# %%
sns.set_theme()

# %%
sns.relplot(data = tips, x="total_bill",col="time",y="tip",hue="smoker", style = "smoker",size="size")
plt.show()

# %%
iris = sns.load_dataset("iris")

# %%
iris.groupby("species")["petal_width"].mean()
iris["species"].value_counts()
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
sns.scatterplot(x="sepal_length",y="petal_length", hue="species",data=iris)
plt.show()

# %%
sns.scatterplot(x="petal_length",y="petal_width", hue="species",data=iris)
plt.show()

# %%
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x="sex", data = titanic)
plt.show()
sns.countplot(x="class", data=titanic)
plt.show()

# %%
titanic.head()
titanic["survived"].value_counts()
sns.barplot(x="sex", y = "survived", hue="class", data=titanic)
plt.show()

# %%
from sklearn.datasets import load_boston
bostan_ds = load_boston()

# %%
houses = pd.DataFrame(bostan_ds.data, columns=bostan_ds.feature_names)
houses
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
houses["PRICE"] = bostan_ds.target

# %%
houses.head(5)

# DIstribution plot 
# sns.displot(houses["PRICE"])
# plt.show()
sns.distplot(houses["PRICE"])
plt.show()
# Out:
# C:\Users\Abdullah khan\AppData\Local\Temp\ipykernel_14004\2920852275.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(houses["PRICE"])

# %%
# Corelation method 
corelation = houses.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corelation, cbar=True,square=True,  annot=True, annot_kws={'size':8}, cmap='Blues')
plt.show()
